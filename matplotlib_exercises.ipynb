# %% [markdown]
# # Matplotlib Exercises
# <hr style="border:2px solid blue"> </hr>
#
# ### 1. Use matplotlib to plot the following equation:
#
# y = x<sup>2</sup> − x + 2
#
# You'll need to write the code that generates the x and y points.
#
# Add an anotation for the point 0, 0, the origin.

# %%
import matplotlib.pyplot as plt  
import math

# %%
#Data Points
x = range(-100,100)
y = [x**2 - x + 2 for x in x] # write the list comprehension

#Plot Lines
plt.plot(x,y,
         color='blue', 
         marker='', 
         linestyle= '-' , 
         label = '$y = x^2 - x + 2$')

#Labels
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()

#Table Design
plt.axis([-40, 40, 0, 1000])

#Annotations 
plt.annotate('Origin', 
             xy=(0,0), 
             xytext=(0,300), 
             arrowprops= dict(facecolor="red"));

# %% [markdown]
# ### 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#
# y = √x
#
# y = x<sup>3</sup>
#
# y = 2<sup>x</sup>
#
# y = 1/(x+1)
#
# You can use functions from the math module to help implement some of the equations above.

# %%
#Data Points
x = range(0,100)
y1 = [ math.sqrt(x) for x in x] # write the list comprehension

#Plot Lines
plt.plot(x,y1,
         color='blue', 
         marker='', 
         linestyle= '-')

#Graph Labels
plt.title('$y = √x$')
plt.xlabel('X axis')
plt.ylabel('Y axis')


#Graph Design
plt.grid('True', ls = '--')
plt.axis([0, 100, 0, 10]);

# %%
#Data Points
x = range(0,100)
y2 = [ x**3 for x in x]

#Plot Lines
plt.plot(x,y2,
         color='green', 
         marker='', 
         linestyle= '-' )

#Labels
plt.title('$y = x^3$')
plt.xlabel('X axis')
plt.ylabel('Y axis')

#Table Design
plt.grid('True', ls = '--')
plt.axis([0, 20, 0, 8000]);

# %%
#Data Points
x3 = [x for x in range(-10,10)]
y3 = [(2**x) for x in x3]

#Plot Lines
plt.plot(x3,y3,
         color='green', 
         marker='', 
         linestyle= '-' )

#Labels
plt.title('$y = 2^x$')
plt.xlabel('X axis')
plt.ylabel('Y axis')

#Table Design
plt.axhline(0, ls="-", lw=0.5, color = "k")#horizontal line
plt.axvline(0, ls="-", lw=0.5, color = "k")#vertical line
plt.grid('True', ls = '--');

plt.axis([-10, 10, 0, 10]);

# %%
#Data Points
x4_1 = range(-100,-1)
x4_2 = range(0,100)
y4_1 = [1/(x+1) for x in x4_1]
y4_2 = [1/(x+1) for x in x4_2]

#Plot Lines
plt.plot(x4_1,y4_1,
         color='green', 
         marker='', 
         linestyle= '-' )
plt.plot(x4_2,y4_2,
         color='green', 
         marker='', 
         linestyle= '-' )

#Labels
plt.title('$y = 1/(x+1)$')
plt.xlabel('X axis')
plt.ylabel('Y axis')

#Table Design
plt.axhline(0, ls="-", lw=0.5, color = "k")#horizontal line
plt.axvline(0, ls="-", lw=0.5, color = "k")#vertical line
plt.grid('True', ls = '--')

plt.axis([-10, 10, -1, 1]);

# %% [markdown]
# ### 3. Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
#Data Points
x = range(0,20) #due to some functions being unable to intake a negative number, we will only plot positives
x3 = [x * 0.1 for x in range(0,150)] #instructor notation for a smoother line!
y1 = [ math.sqrt(x) for x in x] # write the list comprehension
y2 = [ x**3 for x in x]
y3 = [ 2**x for x in x3]
y4 = [1/(x+1) for x in x]

#Figure Details
plt.figure(figsize=(10,10))
plt.suptitle("Fun Math Functions (0,∞)", fontsize = 16)

#SUBPLOT 1
plt.subplot(2,2,1)

#Plot Lines
plt.plot(x,y1,
         color='blue', 
         marker='', 
         linestyle= '-')

#Labels
plt.title('$y = √x$')
plt.xlabel('X axis')
plt.ylabel('Y axis')


#Table Design
plt.axhline(0, ls="-", lw=0.5, color = "k")#horizontal line
plt.axvline(0, ls="-", lw=0.5, color = "k")#vertical line
plt.grid('True', ls = '--')
plt.axis([0, 10, 0, 10])

#SUBPLOT 2
plt.subplot(2,2,2)

#Plot Lines
plt.plot(x,y2,
         color='red', 
         marker='', 
         linestyle= '-' )

#Labels
plt.title('$y = x^3$')
plt.xlabel('X axis')
plt.ylabel('Y axis')

#Table Design
plt.axhline(0, ls="-", lw=0.5, color = "k")#horizontal line
plt.axvline(0, ls="-", lw=0.5, color = "k")#vertical line
plt.grid('True', ls = '--')
plt.axis([0, 10, 0, 10])

#SUBPLOT 3
plt.subplot(2,2,3)

#Plot Lines
plt.plot(x3,y3,
         color='green', 
         marker='', 
         linestyle= '-' )

#Labels
plt.title('$y = 2^x$')
plt.xlabel('X axis')
plt.ylabel('Y axis')

#Table Design
plt.axhline(0, ls="-", lw=0.5, color = "k")#horizontal line
plt.axvline(0, ls="-", lw=0.5, color = "k")#vertical line
plt.grid('True', ls = '--')
plt.axis([0, 10, 0, 10])

#SUBPLOT 4
plt.subplot(2,2,4)

#Plot Lines
plt.plot(x,y4,
         color='orange', 
         marker='', 
         linestyle= '-' )

#Labels
plt.title('$y = 1/(x+1)$')
plt.xlabel('X axis')
plt.ylabel('Y axis')

#Table Design
plt.axhline(0, ls="-", lw=0.5, color = "k")#horizontal line
plt.axvline(0, ls="-", lw=0.5, color = "k")#vertical line
plt.grid('True', ls = '--')
plt.axis([0, 10, 0, 10]);

# %% [markdown]
# ### 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
#Data Points
x = range(0,20)
y1 = [ math.sqrt(x) for x in x] # write the list comprehension
y2 = [ x**3 for x in x]
y3 = [ 2**x for x in x]
y4 = [1/(x+1) for x in x]

#Figure Details
plt.figure(figsize=(10,10))

#Plot Lines
plt.plot(x,y1,
         color='blue', 
         marker='', 
         linestyle= '-',
         label='y = √x')

plt.plot(x,y2,
         color='red', 
         marker='', 
         linestyle= '-',
         label = 'y = x^3')

plt.plot(x,y3,
         color='green', 
         marker='', 
         linestyle= '-',
         label = 'y=2^x')

plt.plot(x,y4,
         color='orange', 
         marker='', 
         linestyle= '-',
         label = '$y = 1/(x+1)$')

#Labels
plt.title('Fun Math Functions (0,∞)', fontsize= 20)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()

#Table Design
plt.axhline(0, ls="-", lw=0.5, color = "k")#horizontal line
plt.axvline(0, ls="-", lw=0.5, color = "k")#vertical line
plt.grid('True', ls = '--')
plt.axis([0, 10, 0, 10]);
