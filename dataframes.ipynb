# %% [markdown]
# # Panda's Dataframes Exercises
# <hr style="border:2px solid orange"> </hr>

# %% [markdown]
# For several of the following exercises, you'll need to load several datasets using the `pydataset` library. (If you get an error when trying to run the import below, use `pip` to install the `pydataset` package.)
#
# `from pydataset import data`
#
# When the instructions say to load a dataset, you can pass the name of the dataset as a string to the `data` function to load the dataset. You can also view the documentation for the data set by passing the `show_doc` keyword argument.
#
# `data('mpg', show_doc=True) # view the documentation for the   dataset
# mpg = data('mpg') # load the dataset and store it in a variable`
#
# All the datasets loaded from the pydataset library will be pandas dataframes.

# %%
from pydataset import data
# Out:
# initiated datasets repo at: /Users/lovelyberserker/.pydataset/

# %% [markdown]
# ### 1. Copy the code from the lesson to create a dataframe full of student grades.

# %%
import pandas as pd
import numpy as np

np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### 1a. Create a column named passing_english that indicates whether each student has a passing grade in english.

# %%
df.assign(passing_english = df.english > 70)
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72            False

# %% [markdown]
# #### 1b. Sort the english grades by the passing_english column. How are duplicates handled?

# %%
df.assign(passing_english = df.english > 70).sort_values(by='passing_english', ascending=False)
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False

# %% [markdown]
# #### 1c. Sort the english grades first by passing_english and then by student name. All the students that are failing english should be first, and within the students that are failing english they should be ordered alphabetically. The same should be true for the students passing english. (Hint: you can pass a list to the .sort_values method)

# %%
df.assign(passing_english = df.english > 70).sort_values(by=['passing_english','name'])
# Out:
#        name  math  english  reading  passing_english
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True

# %% [markdown]
# #### 1d. Sort the english grades first by passing_english, and then by the actual english grade, similar to how we did in the last step.

# %%
df.assign(passing_english = df.english > 70).sort_values(by=['passing_english','english'])
# Out:
#        name  math  english  reading  passing_english
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 2     Suzie    94       74       95             True
# 5      John    79       76       93             True
# 1      Jane    88       79       67             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True

# %% [markdown]
# #### 1.e Calculate each students overall grade and add it as a column on the dataframe. The overall grade is the average of the math, english, and reading grades.

# %%
df.assign(overall_grade = df.english + df.math + df.reading/3)
# Out:
#        name  math  english  reading  overall_grade
# 0     Sally    62       85       80     173.666667
# 1      Jane    88       79       67     189.333333
# 2     Suzie    94       74       95     199.666667
# 3     Billy    98       96       88     223.333333
# 4       Ada    77       92       98     201.666667
# 5      John    79       76       93     186.000000
# 6    Thomas    82       64       81     173.000000
# 7     Marie    93       63       90     186.000000
# 8    Albert    92       62       87     183.000000
# 9   Richard    69       80       94     180.333333
# 10    Isaac    92       99       93     222.000000
# 11     Alan    92       62       72     178.000000

# %% [markdown]
# ### 2. Load the `mpg` dataset. Read the documentation for the dataset and use it for the following questions:

# %%
mpg = data('mpg')

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %% [markdown]
# #### 2a. How many rows and columns are there?

# %%
#234 rows, 11 columns(not including index)
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# #### 2b. What are the data types of each column?

# %%
mpg.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# cty               int64
# hwy               int64
# fl               object
# class            object
# dtype: object

# %% [markdown]
# #### 2c. Summarize the dataframe with `.info` and `.describe`

# %%
mpg.info
# Out:
# <bound method DataFrame.info of     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ...

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# #### - Rename the cty column to city.

# %%
mpg.rename(columns={'cty': 'city'})
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ...

# %% [markdown]
# #### - Rename the hwy column to highway.

# %%
mpg.rename(columns={'hwy': 'highway'})
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17       26  p
#
#        class
# 1    compact
# 2    compact
# ...

# %% [markdown]
# #### - Do any cars have better city mileage than highway mileage?

# %%
mpg[mpg.cty > mpg.hwy]
# Out:
# Empty DataFrame
# Columns: [manufacturer, model, displ, year, cyl, trans, drv, cty, hwy, fl, class]
# Index: []

# %%
mpg.sort_values(by=['cty'],ascending=False)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 222   volkswagen           new beetle    1.9  1999    4  manual(m5)   f   35
# 213   volkswagen                jetta    1.9  1999    4  manual(m5)   f   33
# 223   volkswagen           new beetle    1.9  1999    4    auto(l4)   f   29
# 100        honda                civic    1.6  1999    4  manual(m5)   f   28
# 197       toyota              corolla    1.8  2008    4  manual(m5)   f   28
# ..           ...                  ...    ...   ...  ...         ...  ..  ...
# 70         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
# 66         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 55         dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 60         dodge          durango 4wd    4.7  2008    8    auto(l5)   4    9
# 127         jeep   grand cherokee 4wd    4.7  2008    8    auto(l5)   4    9
#
#      hwy fl       class
# ...

# %% [markdown]
# ### - Create a column named mileage_difference this column should contain the difference between highway and city mileage for each car.

# %%
mpg.assign(mileage_difference = mpg.hwy - mpg.cty)
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference
# 1    compact                  11
# 2    compact                   8
# ...

# %% [markdown]
# ### - Which car (or cars) has the highest mileage difference?

# %%
mpg.assign(mileage_difference = mpg.hwy - mpg.cty).sort_values('mileage_difference',ascending=False).head()
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  cty  hwy fl  \
# 107        honda       civic    1.8  2008    4  auto(l5)   f   24   36  c
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f   29   41  d
# 1           audi          a4    1.8  1999    4  auto(l5)   f   18   29  p
# 229   volkswagen      passat    1.8  1999    4  auto(l5)   f   18   29  p
# 36     chevrolet      malibu    3.5  2008    6  auto(l4)   f   18   29  r
#
#           class  mileage_difference
# 107  subcompact                  12
# 223  subcompact                  12
# 1       compact                  11
# 229     midsize                  11
# 36      midsize                  11

# %% [markdown]
# ### - Which compact class car has the lowest highway mileage? The best?

# %%
#lowest highway mileage
mpg[mpg['class'] == "compact"].sort_values('hwy').head(1)
# Out:
#     manufacturer  model  displ  year  cyl     trans drv  cty  hwy fl    class
# 220   volkswagen  jetta    2.8  1999    6  auto(l4)   f   16   23  r  compact

# %%
#highest highway mileage
mpg[mpg['class'] == "compact"].sort_values('hwy').tail(1)
# Out:
#     manufacturer  model  displ  year  cyl       trans drv  cty  hwy fl  \
# 213   volkswagen  jetta    1.9  1999    4  manual(m5)   f   33   44  d
#
#        class
# 213  compact

# %% [markdown]
# ### - Create a column named average_mileage that is the mean of the city and highway mileage.

# %%
mpg.assign(average_mileage = (mpg.hwy + mpg.cty) / 2 )
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  average_mileage
# 1    compact             23.5
# 2    compact             25.0
# ...

# %% [markdown]
# ### - Which dodge car has the best average mileage? The worst?

# %%
#worst average mileage
mpg.assign(average_mileage = (mpg.hwy + mpg.cty) / 2 )[mpg['manufacturer'] == "dodge"].sort_values('average_mileage').head(1)
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  cty  \
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
#
#     hwy fl   class  average_mileage
# 70   12  e  pickup             10.5

# %%
#best average mileage
mpg.assign(average_mileage = (mpg.hwy + mpg.cty) / 2 )[mpg['manufacturer'] == "dodge"].sort_values('average_mileage').tail(1)
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  cty  hwy fl  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f   18   24  r
#
#       class  average_mileage
# 38  minivan             21.0

# %% [markdown]
# ### 3. Load the `Mammals` dataset. Read the documentation for it, and use the data to answer these questions:

# %%
mammals = data('Mammals')

# %%
mammals
# Out:
#        weight  speed  hoppers  specials
# 1    6000.000   35.0    False     False
# 2    4000.000   26.0    False     False
# 3    3000.000   25.0    False     False
# 4    1400.000   45.0    False     False
# 5     400.000   70.0    False     False
# 6     350.000   70.0    False     False
# 7     300.000   64.0    False     False
# 8     260.000   70.0    False     False
# 9     250.000   40.0    False     False
# 10   3800.000   25.0    False      True
# 11   1000.000   60.0    False     False
# 12    900.000   70.0    False     False
# 13    900.000   56.0    False     False
# 14    800.000   29.0    False     False
# 15    750.000   57.0    False     False
# 16    500.000   32.0    False     False
# 17    450.000   56.0    False     False
# 18    300.000   72.0    False     False
# 19    300.000   90.0    False     False
# 20    250.000   80.0    False     False
# 21    250.000   56.0    False     False
# 22    170.000   80.0    False     False
# ...

# %% [markdown]
# ### - How many rows and columns are there?

# %%
mammals.shape
# Out:
# (107, 4)

# %% [markdown]
# ### - What are the data types?

# %%
mammals.dtypes
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %% [markdown]
# ### - Summarize the dataframe with .info and .describe

# %%
mammals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %%
mammals.describe()
# Out:
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %% [markdown]
# ### - What is the the weight of the fastest animal?

# %%
mammals.sort_values("weight").tail(1).weight
# Out:
# 1    6000.0
# Name: weight, dtype: float64

# %% [markdown]
# ### - What is the overall percentage of specials?

# %%
mammals[mammals.specials].size
# Out:
# 40

# %%
mammals.size
# Out:
# 428

# %%
print(round((mammals[mammals.specials].size / mammals.size) * 100, 2), "%")
# Out:
# 9.35 %

# %% [markdown]
# ### - How many animals are hoppers that are above the median speed? What percentage is this?

# %%
mammals.speed.median()
# Out:
# 48.0

# %%
mammals[(mammals.hoppers) & (mammals.speed > mammals.speed.median())].size
# Out:
# 28

# %%
print(round(( mammals[(mammals.hoppers) & (mammals.speed > mammals.speed.median())].size / mammals.size) * 100, 2), "%")
# Out:
# 6.54 %
